# %% [markdown]
# ## Generate masked lung images

# %%
# %load_ext autoreload
# %autoreload 2

#---setting up the PYTHONPATH------

from pathlib import Path
import sys, os

# Current directory as Path object
current_dir = Path.cwd()
# get project root folder
project_dir = str(current_dir.parent)
# adding project directory to the PYTHONPATH
if project_dir not in sys.path:
    sys.path.append(project_dir)
    print(f"PYTHONPATH added: {project_dir}")
else:
    print("PYTHONPATH was empty or already in sys.path.")

sys.path.append(project_dir)

#----initialize paths and check----
from src import defs

#
from src.utils.datahelper import DataHelper as dh
from src.utils.imgprocessing import ImageProcessor as ip
from src.defs import ModelPath as mp, EXTERNAL_RAW_DEMO_DATA_DIR, EXTERNAL_MASKED_DEMO_DATA_DIR
from tensorflow.keras.models import load_model
# Out:
# PYTHONPATH added: c:\Users\User\DataScience\ds_aug24_lung_desease_classification
#
# PROJECT_DIR:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification
# METADATA_DIR:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\metadata
# IMAGE_DIRECTORIES:  {'COVID': {'images': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\COVID\\images', 'masks': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\COVID\\masks'}, 'Lung_Opacity': {'images': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Lung_Opacity\\images', 'masks': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Lung_Opacity\\masks'}, 'Normal': {'images': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Normal\\images', 'masks': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Normal\\masks'}, 'Viral Pneumonia': {'images': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Viral Pneumonia\\images', 'masks': 'c:\\Users\\User\\DataScience\\ds_aug24_lung_desease_classification\\data\\COVID-19_Radiography_Dataset\\Viral Pneumonia\\masks'}}
# TRAINIG_DATA_DIR_254_IMG_ORIENTATION:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\data_224x224\train_val_224x224
# TRULY_ROTATED_IMG_224:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\224x224_truly_rotated
# TRAINIG_DATA_DIR_256_MASKED_IMBALANCED:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\256x256_masked_images_imbalanced
# TRAINIG_DATA_DIR_256_MASKED_BALANCED:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\256x256_masked_images_balanced
# MLRUNS_URI:  file:///c:/Users/User/DataScience/ds_aug24_lung_desease_classification/mlruns_vst
# MODELS_DIR:  c:\Users\User\DataScience\ds_aug24_lung_desease_classification\models

# %%
model = load_model(mp.GAN, compile=False)
imgs, names = ip.generate_masked_images(
    from_dir=EXTERNAL_RAW_DEMO_DATA_DIR,
    model=model, 
    target_size=(256, 256)
)

ip.plot_images(imgs, names)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#   5%|▌         | 1/20 [00:01<00:30,  1.62s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
#  10%|█         | 2/20 [00:01<00:15,  1.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
#  15%|█▌        | 3/20 [00:02<00:10,  1.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
#  20%|██        | 4/20 [00:02<00:08,  1.94it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
#  25%|██▌       | 5/20 [00:02<00:06,  2.22it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
#  30%|███       | 6/20 [00:03<00:05,  2.44it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
#  35%|███▌      | 7/20 [00:03<00:05,  2.32it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
#  40%|████      | 8/20 [00:04<00:04,  2.48it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
#  45%|████▌     | 9/20 [00:04<00:04,  2.65it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
#  50%|█████     | 10/20 [00:04<00:03,  2.77it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
#  55%|█████▌    | 11/20 [00:05<00:03,  2.83it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
#  60%|██████    | 12/20 [00:05<00:02,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
#  65%|██████▌   | 13/20 [00:05<00:02,  2.91it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
#  70%|███████   | 14/20 [00:06<00:02,  2.96it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
#  75%|███████▌  | 15/20 [00:06<00:01,  3.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
#  80%|████████  | 16/20 [00:06<00:01,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
#  85%|████████▌ | 17/20 [00:07<00:01,  2.69it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
#  90%|█████████ | 18/20 [00:07<00:00,  2.77it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
#  95%|█████████▌| 19/20 [00:07<00:00,  2.79it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 100%|██████████| 20/20 [00:08<00:00,  2.41it/s]

# %%
type(imgs[0])
# Out:
# numpy.ndarray
